# %% [markdown]
# Q1. What is the difference between a function and a method in Python
# - Function: A block of reusable code that performs a specific task. It is independent and defined using def.
# - eg -def greet():print("Hello!")
# - Method: A function associated with an object. It is called using the dot (.) notation.
# - eg text = "hello" ; print(text.upper())

# %% [markdown]
# Q2. Explain the concept of function arguments and parameters in Python.
# - Parameter: A variable defined in the function definition.
# - eg def add(a, b): return a + b
# - Argument: The actual value passed when calling the function.
# - eg add(3, 4)

# %% [markdown]
# Q3. What are the different ways to define and call a function in Python
# - 1. Normal function definition:
# - def say(): print("Hello"); say()
# - 2. With parameters
# - def greet(name):print("Hello", name); greet("Mayank")
# - 3. **Using *args and kwargs:
# - def show(*args, **kwargs):print(args, kwargs); show(1, 2, name="Alice")

# %% [markdown]
# Q4. What is the purpose of the return statement in a Python function?
# - It ends the function and sends a value back to the caller.
# - def multiply(a, b): return a * b

# %% [markdown]
# Q5. What are iterators in Python and how do they differ from iterables?
# - Iterable: An object that can be looped over like lists, strings.
# - numbers = [1, 2, 3]
# - Iterators: the object that gives one item at a time from a collection.
# - it = iter(numbers); print(next(it))

# %% [markdown]
# Q6. Explain the concept of generators in Python and how they are defined.
# - A generator is a special function that yields values one at a time using the yield keyword.
# - def count_up_to(n): i = 1; while i <= n: yield i; i += 1

# %% [markdown]
# Q7. What are the advantages of using generators over regular functions?
# - Memory efficient
# - Faster execution.
# - Generates values one by one on demand.

# %% [markdown]
# Q8. What is a lambda function in Python and when is it typically used?
# - it is a anonymous  one-line function
# - Used for short tasks
# - square = lambda x: x * x ; print(square(4))

# %% [markdown]
# Q9. Explain the purpose and usage of the map() function in Python.
# - map applies a function to each item in an iterable
# - nums = [1, 2, 3];  squares = map(lambda x: x ** 2, nums)

# %% [markdown]
# Q10. What is the difference between map(), reduce(), and filter() functions in Python
# - map: Transforms all items
# - filter: Selects items matching a condition
# - reduce: Combines items to a single value

# %% [markdown]
# Q11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13];
# - from functools import reduce
# - reduce(lambda x, y: x + y, [47, 11, 42, 13])![WhatsApp Image 2025-06-27 at 16.40.04_b22a9587.jpg](data:image/jpeg;base64,...)
# - output : 113

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
from functools import reduce
def even_sum(number):
  even = filter(lambda x : x%2==0,number)
  return reduce(lambda x,y:x+y,even)

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.
def reverse(string):
  return string[::-1]

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def square(number):
  return list(map(lambda x:x**2 ,number))

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True
for num in range(1, 201):
    if is_prime(num):
        print(num, "is a prime number")
# Out:
# 2 is a prime number
# 3 is a prime number
# 5 is a prime number
# 7 is a prime number
# 11 is a prime number
# 13 is a prime number
# 17 is a prime number
# 19 is a prime number
# 23 is a prime number
# 29 is a prime number
# 31 is a prime number
# 37 is a prime number
# 41 is a prime number
# 43 is a prime number
# 47 is a prime number
# 53 is a prime number
# 59 is a prime number
# 61 is a prime number
# 67 is a prime number
# 71 is a prime number
# 73 is a prime number
# 79 is a prime number
# 83 is a prime number
# 89 is a prime number
# 97 is a prime number
# 101 is a prime number
# 103 is a prime number
# 107 is a prime number
# 109 is a prime number
# 113 is a prime number
# 127 is a prime number
# 131 is a prime number
# 137 is a prime number
# 139 is a prime number
# 149 is a prime number
# 151 is a prime number
# 157 is a prime number
# 163 is a prime number
# 167 is a prime number
# 173 is a prime number
# 179 is a prime number
# 181 is a prime number
# ...

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
def fibonacci(n):
    a, b = 0, 1
    for _ in range(n):
        yield a
        a, b = b, a + b

x = fibonacci(10)
next(x)
# Out:
# 0

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
def pow(num):
    for i in range(1,num):
        yield 2 ** i
x = pow(10)
next(x)
# Out:
# 2

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.
def rea(text):
  for i in text:
    yield i
x = rea("hello")
next(x)
# Out:
# 'h'

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple
def sor(tup):
    return sorted(tup, key=lambda x: x[1])

sor([(1, 2, 5), (3, 1, 6), (2, 4, 7)])
# Out:
# [(3, 1, 6), (1, 2, 5), (2, 4, 7)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
def temp(lis):
    return list(map(lambda x: (x * 9/5) + 32, lis))

temp([32,46,98])
# Out:
# [89.6, 114.8, 208.4]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
def rem(text):
    vowels = 'aeiouAEIOU'
    filtered = filter(lambda ch: ch not in vowels, text)
    for ch in filtered:
        print(ch, end="")
rem("hello world")
# Out:
# hll wrld

# %%
# Q11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
# Write a Python program using lambda and map.
def process_orders(orders):
    return list(map(lambda order: (order[0], (order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0))), orders))
orders = [
    ["34587", "Learning Python, Mark Lutz", 4, 40.95],
    ["98762", "Programming Python, Mark Lutz", 5, 56.80],
    ["77226", "Head First Python, Paul Barry", 3, 32.95],
    ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]
]

result = process_orders(orders)
print(result)
# Out:
# [('34587', 163.8), ('98762', 284.0), ('77226', 108.85000000000001), ('88112', 84.97)]
